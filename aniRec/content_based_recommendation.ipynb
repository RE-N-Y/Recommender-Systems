# %% [markdown]
# #Content-based recommendations
# Although deep-learning seems to be leading the trend with recommendation engines, classic content-based recommendations are still very effective methods for recommending items to users. In this notebook, we will explore how we can use different similarity metrics and NLP techniques for content-based recommendations

# %%
#mount driver with data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Get lastest verison of pandas and nltk package for NLP

# %%
# !pip install nltk
# !pip install pandas==0.23.4
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.11.0)
# Collecting pandas==0.23.4
#   Downloading https://files.pythonhosted.org/packages/e1/d8/feeb346d41f181e83fba45224ab14a8d8af019b48af742e047f3845d8cff/pandas-0.23.4-cp36-cp36m-manylinux1_x86_64.whl (8.9MB)
#     100% |████████████████████████████████| 8.9MB 3.8MB/s
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.4) (1.14.6)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.4) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.4) (2018.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.5.0->pandas==0.23.4) (1.11.0)
# Installing collected packages: pandas
#   Found existing installation: pandas 0.22.0
#     Uninstalling pandas-0.22.0:
#       Successfully uninstalled pandas-0.22.0
# Successfully installed pandas-0.23.4

# %%
import json
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, pairwise_distances
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import nltk
#download nltk stopwords and corpus
nltk.download('stopwords')
nltk.download('wordnet')
#read item data
animes = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/aniRec/data/processed_anime.csv")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
animes
# Out:
#        Unnamed: 0  anime_id  \
# 0               0     11013
# 1               1      2104
# 2               2      5262
# 3               3       721
# 4               4     12365
# 5               5      6586
# 6               6       178
# 7               7      2787
# 8               8      4477
# 9               9       853
# 10             10      4814
# 11             11      7054
# 12             12     11123
# 13             13     14227
# 14             14       269
# 15             15        59
# 16             16      6045
# 17             17      1735
# 18             18       210
# 19             19      4224
# 20             20     10030
# 21             21        74
# 22             22      4722
# 23             23     14397
# 24             24      1557
# 25             25     10800
# 26             26      3731
# 27             27      9513
# 28             28      5835
# 29             29      9863
# ...           ...       ...
# 13226       13226     26103
# 13227       13227     37554
# 13228       13228     30930
# 13229       13229     35175
# 13230       13230     30931
# 13231       13231     36324
# 13232       13232     35130
# 13233       13233     26253
# 13234       13234     35151
# 13235       13235     33823
# 13236       13236     37535
# 13237       13237     34237
# 13238       13238     37852
# 13239       13239     30928
# 13240       13240     37463
# 13241       13241     37787
# 13242       13242     35229
# 13243       13243     27579
# 13244       13244     36640
# 13245       13245     35085
# 13246       13246     35152
# 13247       13247     27853
# 13248       13248     36315
# 13249       13249     28569
# 13250       13250     35040
# 13251       13251     26089
# 13252       13252     21525
# 13253       13253     37897
# 13254       13254     34193
# 13255       13255     37908
#
#                                                    title     type  \
# 0                                          Inu x Boku SS       TV
# 1                                       Seto no Hanayome       TV
# 2                                     Shugo Chara!! Doki       TV
# 3                                          Princess Tutu       TV
# 4                                    Bakuman. 3rd Season       TV
# 5                                    Yume-iro Pâtissière       TV
# 6                                           Ultra Maniac       TV
# 7                          Shakugan no Shana II (Second)       TV
# 8                            Nodame Cantabile: Paris-hen       TV
# 9                                 Ouran Koukou Host Club       TV
# 10                                    Junjou Romantica 2       TV
# 11                                 Kaichou wa Maid-sama!       TV
# 12                                  Sekaiichi Hatsukoi 2       TV
# 13                                Tonari no Kaibutsu-kun       TV
# 14                                                Bleach       TV
# 15                                               Chobits       TV
# 16                                        Kimi ni Todoke       TV
# 17                                    Naruto: Shippuuden       TV
# 18                                               Ranma ½       TV
# 19                                             Toradora!       TV
# 20                                   Bakuman. 2nd Season       TV
# 21                                          Gakuen Alice       TV
# 22                                            Skip Beat!       TV
# 23                                         Chihayafuru 2       TV
# 24                                      Shounen Onmyouji       TV
# 25                                           Chihayafuru       TV
# 26                                       Itazura na Kiss       TV
# 27                                             Beelzebub       TV
# 28                                 Hanasakeru Seishounen       TV
# 29                                            SKET Dance       TV
# ...                                                  ...      ...
# 13226                      Namae... Sore wa Moeru Inochi      OVA
# 13227                                     Yousei Tin Tin      ONA
# 13228                      Mameushi-kun no Koutsuu Anzen      OVA
# 13229                             Osakini Douzo Arigatou      OVA
# 13230                     Usagi to Kame no Koutsuu Anzen      OVA
# 13231                          Nijiiro no Fushigina Ishi      OVA
# 13232           Tat-chan - Momo-chan no Fushigina Taiken      OVA
# 13233                        Mina no Mura no Gomi Soudou      OVA
# 13234          Quiz de Manabu Pinocchio no Koutsuu Ansen      OVA
# 13235                            Genbaku Dome Monogatari      OVA
# 13236                                    Asunal Kanayama  Special
# 13237                                   Miraijin Go Home      ONA
# 13238                                            AriKiri      ONA
# 13239  Tobidashi wa Abunaizo! Mushi Mushi Mura no Kou...      OVA
# 13240                                        Rifujin-jin    Music
# 13241                                          Space Bug       TV
# 13242                                Mr. Men Little Miss      ONA
# 13243                               Mii-chan no Tenohira    Movie
# 13244                                      Mashiro Witch      ONA
# 13245               Kyouiku Eiga-sai Jushou Anime Series      OVA
# 13246  Chounai Shinsengumi wo Tasuke-gumi Mezashi-tai...      OVA
# 13247                                     Ichinen Ikkumi      OVA
# 13248  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...      OVA
# 13249                            Kogitsune no Shouboutai      OVA
# 13250                         Minna no Taabou Konnichiwa      OVA
# 13251                         Gutchonpa Omoshiro Hanashi       TV
# 13252                               Geba Geba Shou Time!      OVA
# 13253                        Godzilla: Hoshi wo Kuu Mono    Movie
# 13254              Nippon Mukashibanashi: Sannen Netarou      OVA
# 13255                         Senjou no Valkyria Special  Special
#
#              source  episodes            status  duration  \
# 0             Manga        12   Finished Airing        24
# 1             Manga        26   Finished Airing        24
# 2             Manga        51   Finished Airing        24
# 3          Original        38   Finished Airing        16
# 4             Manga        25   Finished Airing        24
# 5             Manga        50   Finished Airing        24
# 6             Manga        26   Finished Airing        24
# 7       Light novel        24   Finished Airing        24
# 8             Manga        11   Finished Airing        23
# 9             Manga        26   Finished Airing        23
# 10            Manga        12   Finished Airing        24
# 11            Manga        26   Finished Airing        24
# 12            Manga        12   Finished Airing        24
# 13            Manga        13   Finished Airing        24
# 14            Manga       366   Finished Airing        24
# 15            Manga        26   Finished Airing        24
# 16            Manga        25   Finished Airing        22
# 17            Manga       500   Finished Airing        23
# 18            Manga       161   Finished Airing        24
# 19      Light novel        25   Finished Airing        24
# 20            Manga        25   Finished Airing        24
# 21            Manga        26   Finished Airing        25
# 22            Manga        25   Finished Airing        24
# 23            Manga        25   Finished Airing        22
# 24      Light novel        26   Finished Airing        23
# 25            Manga        25   Finished Airing        22
# 26            Manga        25   Finished Airing        24
# 27            Manga        60   Finished Airing        24
# 28            Manga        39   Finished Airing        24
# 29            Manga        77   Finished Airing        24
# ...             ...       ...               ...       ...
# 13226       Unknown         1   Finished Airing        18
# 13227      Original         0  Currently Airing         5
# 13228       Unknown         1   Finished Airing        12
# 13229      Original         1   Finished Airing        14
# 13230       Unknown         1   Finished Airing        13
# 13231      Original         1   Finished Airing        15
# 13232      Original         1   Finished Airing        15
# 13233       Unknown         1   Finished Airing        22
# 13234      Original         1   Finished Airing        15
# 13235         Other         1   Finished Airing        15
# 13236      Original         2   Finished Airing         0
# 13237      Original         0  Currently Airing         3
# 13238         Other         0  Currently Airing         2
# 13239       Unknown         1   Finished Airing        12
# 13240      Original         1   Finished Airing         2
# 13241      Original         0     Not yet aired         0
# 13242  Picture book         0  Currently Airing         2
# 13243       Unknown         1   Finished Airing        20
# 13244          Game         1   Finished Airing         2
# 13245         Other         1   Finished Airing        87
# 13246      Original         1   Finished Airing        13
# 13247       Unknown         1   Finished Airing        51
# 13248      Original         1   Finished Airing        13
# 13249       Unknown         1   Finished Airing        17
# 13250      Original         1   Finished Airing        20
# 13251       Unknown         5   Finished Airing         8
# 13252       Unknown         1   Finished Airing        25
# 13253         Other         1     Not yet aired         0
# 13254         Other         1   Finished Airing        40
# 13255       Unknown         1   Finished Airing         3
#
#                                rating  score       ...        related_animes  \
# 0           PG-13 - Teens 13 or older   7.63       ...                    []
# 1           PG-13 - Teens 13 or older   7.89       ...                    []
# 2                       PG - Children   7.55       ...                    []
# 3           PG-13 - Teens 13 or older   8.21       ...                    []
# 4           PG-13 - Teens 13 or older   8.67       ...                    []
# 5                        G - All Ages   8.03       ...                    []
# 6                        G - All Ages   7.26       ...                    []
# 7           PG-13 - Teens 13 or older   7.72       ...                 [355]
# 8           PG-13 - Teens 13 or older   8.24       ...                    []
# 9           PG-13 - Teens 13 or older   8.34       ...                    []
# 10          PG-13 - Teens 13 or older   8.15       ...                    []
# 11          PG-13 - Teens 13 or older   8.20       ...                    []
# 12          PG-13 - Teens 13 or older   8.23       ...                    []
# 13          PG-13 - Teens 13 or older   7.71       ...                    []
# 14          PG-13 - Teens 13 or older   7.90       ...                    []
# 15          PG-13 - Teens 13 or older   7.53       ...                    []
# 16          PG-13 - Teens 13 or older   8.13       ...                    []
# 17          PG-13 - Teens 13 or older   8.18       ...                  [20]
# 18                   R+ - Mild Nudity   7.85       ...                    []
# 19          PG-13 - Teens 13 or older   8.39       ...                    []
# 20          PG-13 - Teens 13 or older   8.49       ...                    []
# 21                       G - All Ages   7.77       ...                    []
# 22          PG-13 - Teens 13 or older   8.24       ...                    []
# 23          PG-13 - Teens 13 or older   8.47       ...                    []
# 24          PG-13 - Teens 13 or older   7.68       ...                    []
# 25          PG-13 - Teens 13 or older   8.29       ...                    []
# 26          PG-13 - Teens 13 or older   7.70       ...                    []
# 27          PG-13 - Teens 13 or older   8.02       ...                    []
# 28          PG-13 - Teens 13 or older   7.87       ...                    []
# 29          PG-13 - Teens 13 or older   8.33       ...                    []
# ...                               ...    ...       ...                   ...
# 13226                    G - All Ages   8.20       ...                    []
# 13227                            None   5.00       ...                    []
# 13228                    G - All Ages   5.80       ...                    []
# 13229                    G - All Ages   3.00       ...                    []
# 13230                    G - All Ages   4.00       ...                    []
# 13231                    G - All Ages   1.00       ...                    []
# 13232                    G - All Ages   9.50       ...                    []
# 13233                    G - All Ages   5.43       ...                    []
# 13234                    G - All Ages   8.00       ...                    []
# 13235                   PG - Children   6.60       ...                    []
# 13236                    G - All Ages   4.33       ...                    []
# 13237                    G - All Ages   4.50       ...                    []
# 13238                    G - All Ages   3.00       ...                    []
# 13239                    G - All Ages   3.57       ...                    []
# 13240                    G - All Ages   4.38       ...                    []
# 13241                            None   0.00       ...                    []
# 13242                    G - All Ages   4.57       ...                    []
# 13243                    G - All Ages   6.60       ...                    []
# 13244       PG-13 - Teens 13 or older   4.57       ...                    []
# 13245                    G - All Ages  10.00       ...                    []
# 13246                    G - All Ages   5.00       ...                    []
# 13247                    G - All Ages   4.33       ...                    []
# 13248                    G - All Ages   7.00       ...                    []
# 13249                    G - All Ages   7.00       ...                    []
# 13250                    G - All Ages   6.75       ...                    []
# 13251                    G - All Ages   5.50       ...                    []
# 13252                    G - All Ages   4.60       ...                    []
# 13253  R - 17+ (violence & profanity)   0.00       ...                    []
# 13254                    G - All Ages   6.00       ...                    []
# 13255       PG-13 - Teens 13 or older   5.15       ...                    []
#
#        related_manga                                             Staffs  \
# 0                 []  ['Nakamura, Yuuichi', 'Hidaka, Rina', 'Hanazaw...
# 1                 []  ['Momoi, Haruko', 'Mizushima, Takahiro', 'Noga...
# 2                 []  ['Sawashiro, Miyuki', 'Itou, Kanae', 'Chiba, S...
# 3                 []  ['Katou, Nanae', 'Sakurai, Takahiro', 'Mizuki,...
# 4                 []  ['Abe, Atsushi', 'Hino, Satoshi', 'Okamoto, No...
# 5                 []  ['Okamoto, Nobuhiko', 'Yuuki, Aoi', 'Yonaga, T...
# 6                 []  ['Kanda, Akemi', 'Horie, Yui', 'Chiba, Susumu'...
# 7             [3074]  ['Kugimiya, Rie', 'Hino, Satoshi', 'Kawasumi, ...
# 8                 []  ['Kawasumi, Ayako', 'Seki, Tomokazu', 'Ogawa, ...
# 9                 []  ['Miyano, Mamoru', 'Sakamoto, Maaya', 'Suzumur...
# 10             [765]  ['Hanada, Hikaru', 'Sakurai, Takahiro', 'Itou,...
# 11                []  ['Okamoto, Nobuhiko', 'Fujimura, Ayumi', 'Igar...
# 12                []  ['Konishi, Katsuyuki', 'Kondou, Takashi', 'Oka...
# 13                []  ['Suzuki, Tatsuhisa', 'Tomatsu, Haruka', 'Tane...
# 14                []  ['Matsuoka, Yuki', 'Orikasa, Fumiko', 'Matsuok...
# 15                []  ['Tanaka, Rie', 'Sugita, Tomokazu', 'Kumai, Mo...
# 16                []  ['Noto, Mamiko', 'Namikawa, Daisuke', 'Nakamur...
# 17                []  ['Takeuchi, Junko', 'Inoue, Kazuhiko', 'Sugiya...
# 18                []  ['Hayashibara, Megumi', 'Hidaka, Noriko', 'Yam...
# 19                []  ['Kugimiya, Rie', 'Majima, Junji', 'Horie, Yui...
# 20                []  ['Abe, Atsushi', 'Hino, Satoshi', 'Okamoto, No...
# 21                []  ['Park, Romi', 'Ueda, Kana', 'Kugimiya, Rie', ...
# 22                []  ['Inoue, Marina', 'Konishi, Katsuyuki', 'Miyan...
# 23                []  ['Seto, Asami', 'Miyano, Mamoru', 'Terasaki, Y...
# 24                []  ['Konishi, Katsuyuki', 'Kaida, Yuki', 'Ishida,...
# 25                []  ['Seto, Asami', 'Miyano, Mamoru', 'Terasaki, Y...
# 26                []  ['Mizuki, Nana', 'Hirakawa, Daisuke', 'Matsui,...
# 27                []  ['Konishi, Katsuyuki', 'Sawashiro, Miyuki', 'I...
# 28                []  ['Morikawa, Toshiyuki', 'Namikawa, Daisuke', '...
# 29                []  ['Yoshino, Hiroyuki', 'Sugita, Tomokazu', 'Shi...
# ...              ...                                                ...
# 13226             []                                                 []
# 13227             []                                                 []
# 13228             []                                                 []
# 13229             []                                                 []
# 13230             []                                                 []
# 13231             []                                                 []
# 13232             []                                                 []
# 13233             []                                                 []
# 13234             []                                                 []
# 13235             []                                                 []
# 13236             []                                 ['Rabbit MACHINE']
# 13237             []                                                 []
# 13238             []                                                 []
# 13239             []                                                 []
# 13240             []                                                 []
# 13241             []                                                 []
# 13242             []                                                 []
# 13243             []  ['Dezaki, Satoshi', 'Shibuichi, Setsuko', 'Ued...
# 13244             []                                                 []
# 13245             []                                                 []
# 13246             []                                                 []
# 13247             []                                                 []
# 13248             []                                                 []
# 13249             []                                                 []
# 13250             []                                                 []
# 13251             []                                                 []
# 13252             []  ['Ginga, Banjou', 'Yamakawa, Norio', 'Matsuura...
# 13253             []  ['Miyano, Mamoru', 'Seshita, Hiroyuki', 'Shizu...
# 13254             []                                                 []
# 13255             []                                                 []
#
#                                               Characters  \
# 0                                                     []
# 1      ['Seto, Sun', 'Michishio, Nagasumi', 'Edomae, ...
# 2      ['Hinamori, Amu', 'Fujisaki, Nagihiko', 'Hotor...
# 3                                                     []
# 4      ['Mashiro, Moritaka', 'Takagi, Akito', 'Niizum...
# 5      ['Kashino, Makoto', 'Amano, Ichigo', 'Hanabusa...
# 6                                        ['Rio', 'Luna']
# 7      ['Shana', 'Sakai, Yuuji', 'Yoshida, Kazumi', '...
# 8      ['Noda, Megumi', 'Chiaki, Shinichi', 'Stresema...
# 9                                                     []
# 10     ['Usami, Akihiko', 'Takahashi, Misaki', 'Kamij...
# 11                   ['Usui, Takumi', 'Ayuzawa, Misaki']
# 12     ['Takano, Masamune', 'Onodera, Ritsu', 'Kisa, ...
# 13                                                    []
# 14     ['Kurosaki, Ichigo', 'Kuchiki, Rukia', 'Inoue,...
# 15     ['Chii', 'Motosuwa, Hideki', 'Sumomo', 'Freya'...
# 16     ['Kuronuma, Sawako', 'Kazehaya, Shouta', 'Sana...
# 17     ['Uzumaki, Naruto', 'Hatake, Kakashi', 'Uchiha...
# 18     ['Saotome, Ranma', 'Tendou, Akane', 'Hibiki, R...
# 19     ['Aisaka, Taiga', 'Takasu, Ryuuji', 'Kushieda,...
# 20     ['Mashiro, Moritaka', 'Takagi, Akito', 'Niizum...
# 21                                                    []
# 22                                                    []
# 23     ['Ayase, Chihaya', 'Mashima, Taichi', 'Wataya,...
# 24                        ['Suzaku', 'Genbu', 'Seiryuu']
# 25     ['Ayase, Chihaya', 'Mashima, Taichi', 'Wataya,...
# 26                                                    []
# 27     ['Oga, Tatsumi', 'Beelzebub IV, Kaiser de Empe...
# 28                                                    []
# 29     ['Fujisaki, Yuusuke', 'Usui, Kazuyoshi', 'Oniz...
# ...                                                  ...
# 13226                                                 []
# 13227                                                 []
# 13228                                                 []
# 13229                                                 []
# 13230                                                 []
# 13231                                                 []
# 13232                                                 []
# 13233                                                 []
# 13234                                                 []
# 13235                                                 []
# 13236                                                 []
# 13237                                                 []
# 13238                                                 []
# 13239                                                 []
# 13240                                                 []
# 13241                                                 []
# 13242                                                 []
# 13243                                                 []
# 13244                                                 []
# 13245                                                 []
# 13246                                                 []
# 13247                                                 []
# 13248                                                 []
# 13249                                                 []
# 13250                                                 []
# 13251                                                 []
# 13252                                                 []
# 13253                                  ['Sakaki, Haruo']
# 13254                                                 []
# 13255                                                 []
#
#                                              Description favorites_ratio  \
# 0      Ririchiyo Shirakiin is the sheltered daughter ...        0.009895
# 1      Michishio Nagasumi's life couldn't be any more...        0.012642
# 2      Now Utau has left Easter and restarted her sin...        0.011436
# 3      In a fairy tale come to life, the clumsy, swee...        0.035837
# 4      Onto their third serialization, manga duo Mori...        0.011392
# 5      Aside from her deep passion for eating cakes, ...        0.018104
# 6      Hideo Middle School eighth-grader Ayu Tateishi...        0.005356
# 7      The heated bond between Shana and Yuji is test...        0.004873
# 8      Having been given the opportunity to study in ...        0.003292
# 9      Haruhi Fujioka is a bright scholarship candida...        0.044673
# 10     The second part of Junjou Romantica continuing...        0.010380
# 11     Being the first female student council preside...        0.027171
# 12                  Second season of Sekaiichi Hatsukoi.        0.008108
# 13     Shizuku Mizutani is apathetic towards her clas...        0.008430
# 14     Ichigo Kurosaki is an ordinary high schooler u...        0.049699
# 15     When computers start to look like humans, can ...        0.010298
# 16     Kuronuma Sawako is completely misunderstood by...        0.019277
# 17     It has been two and a half years since Naruto ...        0.053955
# 18     Ranma Saotome is a top-class martial artist an...        0.020381
# 19     Ryuuji Takasu is a gentle high school student ...        0.038799
# 20     With the serialization of their new manga, "De...        0.005071
# 21     Mikan Sakura is a normal 10-year-old girl. Opt...        0.022287
# 22     Bright, diligent, and yet naïve 16-year-old Ky...        0.028336
# 23     Chihaya Ayase is obsessed with developing her ...        0.009760
# 24     Masahiro is the grandson of the great onmyouji...        0.006950
# 25     Chihaya Ayase, a strong-willed and tomboyish g...        0.021150
# 26     When her newly-built home is razed to the grou...        0.015462
# 27     Ishiyama High is a school populated entirely b...        0.012530
# 28     Kajika Louisa Kugami Burnsworth is the only da...        0.011202
# 29     At Kaimei High School there is a special club ...        0.018992
# ...                                                  ...             ...
# 13226  An educational film about accepting another's ...        0.000000
# 13227                                                NaN        0.000000
# 13228  An educational film about traffic safety stari...        0.000000
# 13229  A little girl loves to play but she has a hard...        0.000000
# 13230  An educational film about traffic safety stari...        0.000000
# 13231  An educational film meant to teach children to...        0.000000
# 13232  Tat-chan and Momo-chan are kindergarteners pla...        0.000000
# 13233  Mina's family has a baby goat, but it dies fro...        0.000000
# 13234             Pinocchio learns about traffic safety.        0.028571
# 13235  An educational film about the A-Bomb Dome, whi...        0.000000
# 13236  Animated commercials for Asunal Kanayama, a la...        0.000000
# 13237  A person from the future visits a girl on her ...        0.000000
# 13238  For Cybozu Inc.'s (a Tokyo-based software comp...        0.000000
# 13239  An educational film about traffic safety starr...        0.000000
# 13240  A song about a child's negative attitude. How ...        0.000000
# 13241  The story takes place in the not so distant fu...        0.000000
# 13242  Sanrio's rendition of the Mr. Men and Little M...        0.020408
# 13243                 Based on the book by Kikuko Inaba.        0.000000
# 13244  The 3DCG animated opening for Square Enix's Ma...        0.000000
# 13245  Educational Film Festival winning anime series...        0.000000
# 13246  A traffic safety video starring the Shinsengum...        0.000000
# 13247  Based on a well known children's book series b...        0.014286
# 13248  An educational film about traffic safety starr...        0.000000
# 13249  The three kitsune brothers have moved away fro...        0.000000
# 13250  Taabou travels around saying "hello" to everyone.        0.000000
# 13251  A short anime that aired during the children's...        0.000000
# 13252        Based on original story by Kinoshita Renzo.        0.000000
# 13253  A door opens, and a golden seal shatters a sta...        0.000000
# 13254  Based on the Japanese folktale of a young man ...        0.000000
# 13255  Fake movie promo video. Included in the DVD vo...        0.000000
#
#         time_bucket  length    rank_bucket duration_bucket
# 0           shinkai    77.0       mediocre          normal
# 1          haruhism   182.0    normal_show          normal
# 2          haruhism   356.0       mediocre          normal
# 3      new_milenium   280.0    normal_show          normal
# 4           shinkai   175.0   quality_show          normal
# 5        monogatari   357.0    normal_show          normal
# 6      new_milenium   175.0       mediocre          normal
# 7          haruhism   175.0       mediocre          normal
# 8          haruhism    70.0      fine_show          normal
# 9          haruhism   175.0      fine_show          normal
# 10         haruhism    77.0    normal_show          normal
# 11       monogatari   175.0    normal_show          normal
# 12       monogatari    77.0      fine_show          normal
# 13          shinkai    84.0       mediocre          normal
# 14     new_milenium  2730.0    normal_show          normal
# 15     new_milenium   175.0       mediocre          normal
# 16       monogatari   175.0    normal_show          normal
# 17         haruhism  3689.0    normal_show          normal
# 18      Ghibiri_era  1259.0    normal_show          normal
# 19         haruhism   175.0      fine_show          normal
# 20       monogatari   175.0   quality_show          normal
# 21     new_milenium   196.0    normal_show          normal
# 22         haruhism   175.0      fine_show          normal
# 23          shinkai   168.0   quality_show          normal
# 24         haruhism   161.0       mediocre          normal
# 25       monogatari   175.0      fine_show          normal
# 26         haruhism   173.0       mediocre          normal
# 27       monogatari   441.0    normal_show          normal
# 28       monogatari   315.0    normal_show          normal
# 29       monogatari   539.0      fine_show          normal
# ...             ...     ...            ...             ...
# 13226       Unknown    56.0  below_average          normal
# 13227       new_age   245.0  below_average           short
# 13228       Unknown    56.0  below_average          normal
# 13229       Unknown    56.0  below_average          normal
# 13230       Unknown    56.0  below_average          normal
# 13231       Unknown    56.0  below_average          normal
# 13232       Unknown    56.0  below_average          normal
# 13233       Unknown    56.0  below_average          normal
# 13234       Unknown    56.0  below_average          normal
# 13235   Ghibiri_era     0.0  below_average          normal
# 13236       shinkai   672.0  below_average           short
# 13237       new_age   817.0  below_average           short
# 13238       new_age   476.0  below_average           short
# 13239       Unknown    56.0  below_average          normal
# 13240       Unknown    56.0  below_average           short
# 13241       new_age   142.0        Unknown           short
# 13242       shinkai  1824.0  below_average           short
# 13243      the_90's     0.0  below_average          normal
# 13244       new_age     0.0  below_average           short
# 13245       Unknown    56.0  below_average            long
# 13246       Unknown    56.0  below_average          normal
# 13247       Unknown    56.0  below_average          medium
# 13248       Unknown    56.0  below_average          normal
# 13249       Unknown    56.0  below_average          normal
# 13250       Unknown    56.0  below_average          normal
# 13251   Ghibiri_era   365.0  below_average           short
# 13252   Ghibiri_era     0.0  below_average          normal
# 13253       Unknown    56.0        Unknown           short
# 13254       Unknown    56.0  below_average          normal
# 13255    monogatari     0.0  below_average           short
#
# [13256 rows x 31 columns]

# %% [markdown]
# We can see that we have an extra index as a column. Let's drop that

# %%
animes = animes.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ##Feature engineering for list-like features
#
# Although most of EDA and feature engineering was already finished in our **anime-EDA** notebook, some customizations have to be made. For instance, lists should be changed to string format so that can use get_dummies method for one-hot encoding

# %%
import ast
list_type_features = ['producer','licensor','studio','genre','musicians','related_animes','related_manga','Staffs','Characters']

def process_list(x):
  arr = ast.literal_eval(x)
  return  ",".join(str(x).strip() for x in arr)

for column in list_type_features:
  animes[column] = animes[column].apply(lambda x:process_list(x))
animes[list_type_features]
# Out:
#                                                 producer  \
# 0      Aniplex,Square Enix,Mainichi Broadcasting Syst...
# 1                         TV Tokyo,AIC,Square Enix,Sotsu
# 2                                         TV Tokyo,Sotsu
# 3                       Memory-Tech,GANSIS,Marvelous AQL
# 4                                           NHK,Shueisha
# 5            Yomiuri Telecasting,DAX Production,Shueisha
# 6                                            Studio Jack
# 7       Geneon Universal Entertainment,ASCII Media Works
# 8      Fuji TV,Asmik Ace Entertainment,Sony Music Ent...
# 9               VAP,Hakusensha,Nippon Television Network
# 10            Frontier Works,Kadokawa Shoten,Memory-Tech
# 11     Geneon Universal Entertainment,TBS,Hakusensha,...
# 12                 Lantis,Kadokawa Shoten,AT-X,KlockWorx
# 13            TV Tokyo,Aniplex,Nihon Ad Systems,Kodansha
# 14       TV Tokyo,Aniplex,Dentsu,TV Tokyo Music,Shueisha
# 15                                       TBS,Pioneer LDC
# 16                VAP,Nippon Television Network,Shueisha
# 17     TV Tokyo,Aniplex,KSS,Rakuonsha,TV Tokyo Music,...
# 18     Shogakukan Productions,Kitty Films,Fuji TV,Sho...
# 19     Genco,Starchild Records,Magic Capsule,Yomiuri ...
# 20                                          NHK,Shueisha
# 21                                               Aniplex
# 22           Sotsu,Pony Canyon,Hakusensha,TV Tokyo Music
# 23                         VAP,Nippon Television Network
# 24                                                 Sotsu
# 25                         VAP,Nippon Television Network
# 26                                         Bandai Visual
# 27                   Dentsu,Yomiuri Telecasting,Shueisha
# 28
# 29                    TV Tokyo,Avex Entertainment,Dentsu
# ...                                                  ...
# 13226
# 13227
# 13228
# 13229
# 13230
# 13231
# 13232
# 13233
# 13234
# 13235
# 13236
# 13237
# 13238
# 13239
# 13240                                                NHK
# 13241
# 13242
# 13243                                          Magic Bus
# 13244
# 13245
# 13246
# 13247
# 13248
# 13249
# 13250                                             Sanrio
# 13251
# 13252
# 13253
# 13254
# 13255
#
#                                       licensor                        studio  \
# 0                             Sentai Filmworks              David Production
# 1                                   Funimation                         Gonzo
# 2                                                                  Satelight
# 3                                    ADV Films                Hal Film Maker
# 4                                                                  J.C.Staff
# 5                                               Studio Pierrot,Studio Hibari
# 6      Discotek Media,Geneon Entertainment USA               Production Reed
# 7                                   Funimation                     J.C.Staff
# 8                                                                  J.C.Staff
# 9                                   Funimation                         Bones
# 10                        Nozomi Entertainment                   Studio Deen
# 11                            Sentai Filmworks                     J.C.Staff
# 12                                  Funimation                   Studio Deen
# 13                            NIS America,Inc.             Brain&#039;s Base
# 14                                   Viz Media                Studio Pierrot
# 15         Funimation,Geneon Entertainment USA                      Madhouse
# 16                            NIS America,Inc.                Production I.G
# 17                                   Viz Media                Studio Pierrot
# 18                                   Viz Media                   Studio Deen
# 19                            NIS America,Inc.                     J.C.Staff
# 20                              Media Blasters                     J.C.Staff
# 21                        Nozomi Entertainment                     Group TAC
# 22                                                            Hal Film Maker
# 23                            Sentai Filmworks                      Madhouse
# 24         Funimation,Geneon Entertainment USA                   Studio Deen
# 25                            Sentai Filmworks                      Madhouse
# 26                              Discotek Media             TMS Entertainment
# 27                              Discotek Media                  Pierrot Plus
# 28                                                            Studio Pierrot
# 29                                                      Tatsunoko Production
# ...                                        ...                           ...
# 13226                                                         Toei Animation
# 13227
# 13228                                                         Toei Animation
# 13229
# 13230                                                         Toei Animation
# 13231
# 13232
# 13233
# 13234
# 13235
# 13236
# 13237
# 13238
# 13239                                                         Toei Animation
# 13240
# 13241
# 13242
# 13243
# 13244
# 13245
# 13246
# 13247                                                         Toei Animation
# 13248                                                         Toei Animation
# 13249
# 13250
# 13251
# 13252
# 13253
# 13254
# 13255                                                           A-1 Pictures
#
#                                                    genre  \
# 0                    Comedy,Supernatural,Romance,Shounen
# 1                   Comedy,Parody,Romance,School,Shounen
# 2                             Comedy,Magic,School,Shoujo
# 3                     Comedy,Drama,Magic,Romance,Fantasy
# 4                           Comedy,Drama,Romance,Shounen
# 5                                     Kids,School,Shoujo
# 6                     Magic,Comedy,Romance,School,Shoujo
# 7       Action,Drama,Fantasy,Romance,School,Supernatural
# 8               Music,Slice of Life,Comedy,Romance,Josei
# 9                     Comedy,Harem,Romance,School,Shoujo
# 10                       Comedy,Drama,Romance,Shounen Ai
# 11                          Comedy,Romance,School,Shoujo
# 12                       Comedy,Drama,Romance,Shounen Ai
# 13            Slice of Life,Comedy,Romance,School,Shoujo
# 14     Action,Adventure,Comedy,Super Power,Supernatur...
# 15              Sci-Fi,Comedy,Drama,Romance,Ecchi,Seinen
# 16             Slice of Life,Drama,Romance,School,Shoujo
# 17     Action,Adventure,Comedy,Super Power,Martial Ar...
# 18             Slice of Life,Comedy,Martial Arts,Fantasy
# 19                   Slice of Life,Comedy,Romance,School
# 20                          Comedy,Drama,Romance,Shounen
# 21                      Comedy,School,Shoujo,Super Power
# 22                           Comedy,Drama,Romance,Shoujo
# 23          Drama,Game,Josei,School,Slice of Life,Sports
# 24     Action,Magic,Fantasy,Supernatural,Demons,Histo...
# 25          Drama,Game,Josei,School,Slice of Life,Sports
# 26                                 Comedy,Romance,Shoujo
# 27      Action,Comedy,Demons,Supernatural,School,Shounen
# 28                                  Drama,Romance,Shoujo
# 29                                 Comedy,School,Shounen
# ...                                                  ...
# 13226                                         Drama,Kids
# 13227                       Comedy,Fantasy,Slice of Life
# 13228                                         Drama,Kids
# 13229                                               Kids
# 13230                                 Drama,Fantasy,Kids
# 13231                                               Kids
# 13232                                         Kids,Drama
# 13233                                         Kids,Drama
# 13234                                               Kids
# 13235                                   Drama,Historical
# 13236                                      Slice of Life
# 13237                                             Sci-Fi
# 13238                                      Slice of Life
# 13239                                         Drama,Kids
# 13240                                         Kids,Music
# 13241                                    Adventure,Space
# 13242                                               Kids
# 13243                                   Historical,Drama
# 13244                                         Game,Magic
# 13245                                         Drama,Kids
# 13246                                               Kids
# 13247                                        Kids,School
# 13248                                               Kids
# 13249                                 Drama,Fantasy,Kids
# 13250                                               Kids
# 13251                                               Kids
# 13252                                             Comedy
# 13253                    Action,Sci-Fi,Adventure,Fantasy
# 13254                                       Fantasy,Kids
# 13255                                             Comedy
#
#                                                musicians related_animes  \
# 0                                                   MUCC
# 1
# 2
# 3                                        Ritsuko Okazaki
# 4                   nano.RIPE,Sphere,Hyadain,JAM Project
# 5                                           Mayumi Gojou
# 6                                                can/goo
# 7                                     Mami Kawada,KOTOKO            355
# 8
# 9                                          Chieko Kawabe
# 10
# 11
# 12                                           Shuhei Kita
# 13                                  9nine,Haruka Tomatsu
# 14     SunSet Swish,Asian Kung-Fu Generation,Aimer,UV...
# 15                     Rie Tanaka,ROUND TABLE feat. Nino
# 16                                                 Chara
# 17     MUCC,Hemenway,AZU,Asian Kung-Fu Generation,NIC...             20
# 18
# 19                   Rie Kugimiya,Eri Kitamura,Yui Horie
# 20                                       Tommy heavenly6
# 21                                          Kugimiya Rie
# 22
# 23                                        99RadioService
# 24                                          Kaori Hikita
# 25                                        99RadioService
# 26                                     Motohiro Hata,AZU
# 27                      ON/OFF,FLOW,9nine,Shoko Nakagawa
# 28
# 29                                  Gackt,The Sketchbook
# ...                                                  ...            ...
# 13226
# 13227
# 13228
# 13229
# 13230
# 13231
# 13232
# 13233
# 13234
# 13235
# 13236
# 13237
# 13238
# 13239
# 13240
# 13241
# 13242
# 13243
# 13244
# 13245
# 13246
# 13247
# 13248
# 13249
# 13250
# 13251
# 13252
# 13253
# 13254
# 13255
#
#       related_manga                                             Staffs  \
# 0                    Nakamura, Yuuichi,Hidaka, Rina,Hanazawa, Kana,...
# 1                    Momoi, Haruko,Mizushima, Takahiro,Nogawa, Saku...
# 2                    Sawashiro, Miyuki,Itou, Kanae,Chiba, Saeko,Tak...
# 3                    Katou, Nanae,Sakurai, Takahiro,Mizuki, Nana,Ya...
# 4                    Abe, Atsushi,Hino, Satoshi,Okamoto, Nobuhiko,M...
# 5                    Okamoto, Nobuhiko,Yuuki, Aoi,Yonaga, Tsubasa,T...
# 6                    Kanda, Akemi,Horie, Yui,Chiba, Susumu,Kamiya, ...
# 7              3074  Kugimiya, Rie,Hino, Satoshi,Kawasumi, Ayako,It...
# 8                    Kawasumi, Ayako,Seki, Tomokazu,Ogawa, Shinji,M...
# 9                    Miyano, Mamoru,Sakamoto, Maaya,Suzumura, Kenic...
# 10              765  Hanada, Hikaru,Sakurai, Takahiro,Itou, Kentaro...
# 11                   Okamoto, Nobuhiko,Fujimura, Ayumi,Igarashi, Hi...
# 12                   Konishi, Katsuyuki,Kondou, Takashi,Okamoto, No...
# 13                   Suzuki, Tatsuhisa,Tomatsu, Haruka,Tanezaki, At...
# 14                   Matsuoka, Yuki,Orikasa, Fumiko,Matsuoka, Yuki,...
# 15                   Tanaka, Rie,Sugita, Tomokazu,Kumai, Motoko,Tan...
# 16                   Noto, Mamiko,Namikawa, Daisuke,Nakamura, Yuuic...
# 17                   Takeuchi, Junko,Inoue, Kazuhiko,Sugiyama, Nori...
# 18                   Hayashibara, Megumi,Hidaka, Noriko,Yamadera, K...
# 19                   Kugimiya, Rie,Majima, Junji,Horie, Yui,Kitamur...
# 20                   Abe, Atsushi,Hino, Satoshi,Okamoto, Nobuhiko,M...
# 21                   Park, Romi,Ueda, Kana,Kugimiya, Rie,Ishida, Ak...
# 22                   Inoue, Marina,Konishi, Katsuyuki,Miyano, Mamor...
# 23                   Seto, Asami,Miyano, Mamoru,Terasaki, Yuka,Kaya...
# 24                   Konishi, Katsuyuki,Kaida, Yuki,Ishida, Akira,T...
# 25                   Seto, Asami,Miyano, Mamoru,Terasaki, Yuka,Kaya...
# 26                   Mizuki, Nana,Hirakawa, Daisuke,Matsui, Naoko,P...
# 27                   Konishi, Katsuyuki,Sawashiro, Miyuki,Itou, Shi...
# 28                   Morikawa, Toshiyuki,Namikawa, Daisuke,Endou, A...
# 29                   Yoshino, Hiroyuki,Sugita, Tomokazu,Shiraishi, ...
# ...             ...                                                ...
# 13226
# 13227
# 13228
# 13229
# 13230
# 13231
# 13232
# 13233
# 13234
# 13235
# 13236                                                   Rabbit MACHINE
# 13237
# 13238
# 13239
# 13240
# 13241
# 13242
# 13243                Dezaki, Satoshi,Shibuichi, Setsuko,Ueda, Yoshi...
# 13244
# 13245
# 13246
# 13247
# 13248
# 13249
# 13250
# 13251
# 13252                Ginga, Banjou,Yamakawa, Norio,Matsuura, Noriyoshi
# 13253                Miyano, Mamoru,Seshita, Hiroyuki,Shizuno, Koub...
# 13254
# 13255
#
#                                               Characters
# 0
# 1      Seto, Sun,Michishio, Nagasumi,Edomae, Lunar,Ma...
# 2      Hinamori, Amu,Fujisaki, Nagihiko,Hotori, Tadas...
# 3
# 4      Mashiro, Moritaka,Takagi, Akito,Niizuma, Eiji,...
# 5      Kashino, Makoto,Amano, Ichigo,Hanabusa, Satsuk...
# 6                                               Rio,Luna
# 7      Shana,Sakai, Yuuji,Yoshida, Kazumi,Carmel, Wil...
# 8      Noda, Megumi,Chiaki, Shinichi,Stresemann, Fran...
# 9
# 10     Usami, Akihiko,Takahashi, Misaki,Kamijou, Hiro...
# 11                          Usui, Takumi,Ayuzawa, Misaki
# 12     Takano, Masamune,Onodera, Ritsu,Kisa, Shouta,Y...
# 13
# 14     Kurosaki, Ichigo,Kuchiki, Rukia,Inoue, Orihime...
# 15             Chii,Motosuwa, Hideki,Sumomo,Freya,Kotoko
# 16     Kuronuma, Sawako,Kazehaya, Shouta,Sanada, Ryuu...
# 17     Uzumaki, Naruto,Hatake, Kakashi,Uchiha, Sasuke...
# 18     Saotome, Ranma,Tendou, Akane,Hibiki, Ryouga,Sh...
# 19     Aisaka, Taiga,Takasu, Ryuuji,Kushieda, Minori,...
# 20     Mashiro, Moritaka,Takagi, Akito,Niizuma, Eiji,...
# 21
# 22
# 23     Ayase, Chihaya,Mashima, Taichi,Wataya, Arata,O...
# 24                                  Suzaku,Genbu,Seiryuu
# 25     Ayase, Chihaya,Mashima, Taichi,Wataya, Arata,O...
# 26
# 27     Oga, Tatsumi,Beelzebub IV, Kaiser de Emperana,...
# 28
# 29     Fujisaki, Yuusuke,Usui, Kazuyoshi,Onizuka, Him...
# ...                                                  ...
# 13226
# 13227
# 13228
# 13229
# 13230
# 13231
# 13232
# 13233
# 13234
# 13235
# 13236
# 13237
# 13238
# 13239
# 13240
# 13241
# 13242
# 13243
# 13244
# 13245
# 13246
# 13247
# 13248
# 13249
# 13250
# 13251
# 13252
# 13253                                      Sakaki, Haruo
# 13254
# 13255
#
# [13256 rows x 9 columns]

# %% [markdown]
# Now, let's check data sparcity for which features we can use

# %%
for column in list_type_features:
  print(column+" "+str(animes[animes[column]==''].shape[0]))
# Out:
# producer 7015
# licensor 10272
# studio 5853
# genre 64
# musicians 9925
# related_animes 11547
# related_manga 12538
# Staffs 3898
# Characters 6823

# %% [markdown]
# We can see that a lot of data are missing. We will only consider Staffs, Genre, and Studio features since these are reletively less sparse (especially genre feature) and staffs and studio can affect the show's quality.

# %% [markdown]
# ##Similarity matrix
#
# We will be mainly considering euclidean distance and cosine similarity score as similarity metrics. Jaccard and Pearson coefficients will be also provided as an option for later customizations. Euclidean distance will be used for features with a lot of missing values or if the magnitude fo the feature matters (e.g. time/score)

# %%
#define similarity function
def similarity_matrix(matrix,measure='euclidean'):
  if measure == 'euclidean':
    return 1./(1. + euclidean_distances(matrix)) #take reciprocal to scale between 0~1
  elif measure == 'cosine':
    return cosine_similarity(matrix)
  elif measure == 'pearson':
    return matrix.corr
  elif measure =='jacc':
    return pairwise_distances(matrix,metric='jaccard')

# %%
#use cosine since magnitude doesn't matter and data is sparse (a lot of columns)
genre_sim = similarity_matrix(animes['genre'].str.get_dummies(","),measure='cosine')

# %%
#producer similarity is an option but we are skipping it to save RAM

#use euclidean because there are too many zero vectors (missing values) 
studio_sim = similarity_matrix(animes['studio'].str.get_dummies(","))
similarity = np.multiply(genre_sim,studio_sim)
#producer_sim = similarity_matrix(animes['producer'].str.get_dummies(","))

# %% [markdown]
# ## NLP with description data
#
# A lot of the entries contain the text description of the anime and we will be using TF-IDF vectorizer calculate similarity measures

# %%
#first make sure all data are populated with something
animes['Description'] = animes['Description'].fillna("")

# %%
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
        #use stopwords to remove meaningless words and punctuations
        self.stop = stopwords.words('english')
        #use regex to tokenize words with longer than 3 characters
        self.tokenizer = RegexpTokenizer(r'\w{3,}')
    def __call__(self, articles):
        #tokenize as list if the word is not a punctuation or meaningless word (e.g. is,was,and...)
        return [self.wnl.lemmatize(t) for t in self.tokenizer.tokenize(articles) if t not in self.stop]
#use TfidVectorizer to get term-frequency representaiton of the word
tfidf_vec = TfidfVectorizer(min_df=15,tokenizer=LemmaTokenizer(),stop_words='english')
#use vectorizer on anime descriptions
tfidf_matrix = tfidf_vec.fit_transform(animes['Description']).toarray()
tfidf_feature_names = tfidf_vec.get_feature_names()

#multiply synopsis simlarity to total similarity matrix
similarity = np.multiply(similarity,similarity_matrix(tfidf_matrix,measure='cosine'))

# %%
#check tokens
tfidf_feature_names
# Out:
# ['000',
#  '100',
#  '10th',
#  '11th',
#  '12th',
#  '13th',
#  '14th',
#  '15th',
#  '16th',
#  '17th',
#  '18th',
#  '1945',
#  '1989',
#  '1999',
#  '19th',
#  '1st',
#  '2000',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '20th',
#  '21st',
#  '22nd',
#  '25th',
#  '2nd',
#  '300',
#  '3rd',
#  '4th',
#  '500',
#  '5th',
#  '6th',
#  '7th',
#  '8th',
#  '9th',
#  'abandon',
#  'abandoned',
#  'abducted',
#  'ability',
#  'able',
#  'abnormal',
#  'aboard',
#  'abroad',
#  'absolute',
#  'absolutely',
#  'abuse',
#  'academic',
#  'academy',
#  'accept',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accident',
#  'accidentally',
#  'acclaimed',
#  'accompanied',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'according',
#  'ace',
#  'achieve',
#  'achievement',
#  'achieving',
#  'acquaintance',
#  'acquire',
#  'act',
#  'acting',
#  'action',
#  'active',
#  'activity',
#  'actor',
#  'actress',
#  'actual',
#  'actually',
#  'adapt',
#  'adaptation',
#  'adapted',
#  'adapts',
#  'add',
#  'added',
#  'addition',
#  'additional',
#  'adjust',
#  'adopted',
#  'adoptive',
#  'adorable',
#  'adult',
#  'advance',
#  'advanced',
#  'advantage',
#  'adventure',
#  'adventurer',
#  'adversary',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advisor',
#  'affair',
#  'affect',
#  'affection',
#  'afraid',
#  'aftermath',
#  'age',
#  'aged',
#  'agency',
#  'agenda',
#  'agent',
#  'ago',
#  'agree',
#  'agrees',
#  'ahead',
#  'aid',
#  'aided',
#  'aim',
#  'aimed',
#  'aiming',
#  'air',
#  'aired',
#  'airing',
#  'aka',
#  'akane',
#  'akari',
#  'aki',
#  'akihabara',
#  'akira',
#  'akito',
#  'album',
#  'alice',
#  'alien',
#  'alike',
#  'alive',
#  'alliance',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'alongside',
#  'alter',
#  'alternate',
#  'alternative',
#  'amano',
#  'amazing',
#  'ambition',
#  'ambitious',
#  'america',
#  'american',
#  'amid',
#  'amidst',
#  'amnesia',
#  'amuro',
#  'amusement',
#  'ancestor',
#  'ancient',
#  'android',
#  'angel',
#  'anger',
#  'angry',
#  'animal',
#  'animated',
#  'animation',
#  'animator',
#  'anime',
#  'anna',
#  'anniversary',
#  'announced',
#  'announces',
#  'annual',
#  'anpanman',
#  'answer',
#  'anthropomorphic',
#  'anti',
#  'antic',
#  'anymore',
#  'aoba',
#  'aoi',
#  'apart',
#  'apartment',
#  'apocalypse',
#  'apocalyptic',
#  'app',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'apple',
#  'apprentice',
#  'approach',
#  'approached',
#  'approaching',
#  'april',
#  'arale',
#  'arc',
#  'arcade',
#  'area',
#  'arena',
#  'aria',
#  'arise',
#  'arm',
#  'armed',
#  'armor',
#  'armored',
#  'army',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrogant',
#  'art',
#  'arthur',
#  'artifact',
#  'artificial',
#  'artist',
#  'ash',
#  'asia',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'aspect',
#  'aspiring',
#  'assassin',
#  'assassinate',
#  'assassination',
#  'assault',
#  'assigned',
#  'assignment',
#  'assist',
#  'assistance',
#  'assistant',
#  'assisted',
#  'association',
#  'asteroid',
#  'astronaut',
#  'asuka',
#  'athena',
#  'athletic',
#  'atmosphere',
#  'atomic',
#  'atsushi',
#  'attached',
#  'attack',
#  'attacked',
#  'attacker',
#  'attacking',
#  'attain',
#  'attempt',
#  'attempting',
#  'attend',
#  'attending',
#  'attends',
#  'attention',
#  'attitude',
#  'attract',
#  'attracted',
#  'attraction',
#  'attractive',
#  'audience',
#  'audition',
#  'august',
#  'aunt',
#  'aura',
#  'author',
#  'authority',
#  'available',
#  'avatar',
#  'avenge',
#  'average',
#  'avoid',
#  'avoiding',
#  'await',
#  'awaiting',
#  'awaits',
#  'awaken',
#  'awakened',
#  'awakening',
#  'awakens',
#  'award',
#  'aware',
#  'away',
#  'awkward',
#  'awry',
#  'aya',
#  'ayumi',
#  'baby',
#  'background',
#  'bad',
#  'bag',
#  'baka',
#  'balance',
#  'ball',
#  'ban',
#  'band',
#  'bandai',
#  'bandit',
#  'bang',
#  'bank',
#  'bar',
#  'barely',
#  'bargained',
#  'barrier',
#  'base',
#  'baseball',
#  'based',
#  'basic',
#  'basket',
#  'basketball',
#  'bat',
#  'bath',
#  'battle',
#  'battlefield',
#  'battleship',
#  'battling',
#  'bay',
#  'beach',
#  'bear',
#  'beast',
#  'beat',
#  'beaten',
#  'beautiful',
#  'beauty',
#  'bed',
#  'bee',
#  'befriend',
#  'befriends',
#  'began',
#  'begin',
#  'beginning',
#  'begun',
#  'behavior',
#  'belief',
#  'believe',
#  'believed',
#  'believing',
#  'bell',
#  'belonging',
#  'belongs',
#  'beloved',
#  'belt',
#  'beneath',
#  'benefit',
#  'bent',
#  'best',
#  'betrayal',
#  'betrayed',
#  'better',
#  'bicycle',
#  'bid',
#  'big',
#  'bigger',
#  'biggest',
#  'bike',
#  'billion',
#  'bird',
#  'birth',
#  'birthday',
#  'bit',
#  'bitter',
#  'bizarre',
#  'black',
#  'blade',
#  'blast',
#  'blind',
#  'block',
#  'blood',
#  'bloodshed',
#  'bloody',
#  'bloom',
#  'blossom',
#  'blown',
#  'blu',
#  'blue',
#  'board',
#  'boarding',
#  'boat',
#  'body',
#  'bodyguard',
#  'boku',
#  'bomb',
#  'bombing',
#  'bond',
#  'bone',
#  'bonus',
#  'book',
#  'bored',
#  'boring',
#  'born',
#  'bos',
#  'bottle',
#  'bound',
#  'boundary',
#  'bounty',
#  'box',
#  'boxer',
#  'boxing',
#  'boy',
#  'boyfriend',
#  'brain',
#  'branch',
#  'brand',
#  'brave',
#  'break',
#  'breaking',
#  'bride',
#  'bridge',
#  'brief',
#  'brigade',
#  'bright',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'british',
#  'broadcast',
#  'broadcasted',
#  'broke',
#  'broken',
#  'brother',
#  'brought',
#  'brown',
#  'brutal',
#  'bubble',
#  'buddha',
#  'buddhist',
#  'budding',
#  'buddy',
#  'bug',
#  'build',
#  'building',
#  'built',
#  'bullet',
#  'bullied',
#  'bully',
#  'bullying',
#  'bump',
#  'bunch',
#  'bundled',
#  'bunny',
#  'bureau',
#  'buried',
#  'burning',
#  'bus',
#  'business',
#  'buster',
#  'busy',
#  'butler',
#  'butt',
#  'butterfly',
#  'buy',
#  'cafe',
#  'café',
#  'called',
#  'calling',
#  'calm',
#  'came',
#  'camera',
#  'camp',
#  'campaign',
#  'campus',
#  'candidate',
#  'candy',
#  'capability',
#  'capable',
#  'capital',
#  'capsule',
#  'captain',
#  'captive',
#  'capture',
#  'captured',
#  'capturing',
#  'car',
#  'card',
#  'care',
#  'career',
#  'carefree',
#  'caring',
#  'carry',
#  'carrying',
#  'cartoon',
#  'case',
#  'cast',
#  'castle',
#  'cat',
#  'catastrophe',
#  'catastrophic',
#  'catch',
#  'caught',
#  'cause',
#  'caused',
#  'causing',
#  'cave',
#  'celebrate',
#  'celebrating',
#  'celebration',
#  'cell',
#  'center',
#  'centered',
#  'central',
#  'century',
#  'ceremony',
#  'certain',
#  'certainly',
#  'cgi',
#  'chain',
#  'chairman',
#  'challenge',
#  'challenged',
#  'challenging',
#  'champion',
#  'championship',
#  'chan',
#  'chance',
#  'change',
#  'changed',
#  'changing',
#  'channel',
#  'chaos',
#  'chaotic',
#  'chapter',
#  'char',
#  'character',
#  'charge',
#  'charged',
#  'charm',
#  'charming',
#  'chase',
#  'chased',
#  'chasing',
#  'check',
#  'cheer',
#  'cheerful',
#  'chef',
#  'cherry',
#  'chi',
#  'chiaki',
#  'chiba',
#  'chibi',
#  'chicken',
#  'chief',
#  'child',
#  'childhood',
#  'childish',
#  'china',
#  'chinese',
#  'chip',
#  'chizuru',
#  'chocolate',
#  'choice',
#  'choose',
#  'chooses',
#  'chore',
#  'chose',
#  'chosen',
#  'christian',
#  'christmas',
#  'chronicle',
#  'church',
#  'cinderella',
#  'cinema',
#  'circle',
#  'circumstance',
#  'circus',
#  'citizen',
#  'city',
#  'civil',
#  'civilian',
#  'civilization',
#  'clad',
#  'claim',
#  'claiming',
#  'clan',
#  'clash',
#  'class',
#  'classic',
#  'classical',
#  'classmate',
#  'classroom',
#  'claus',
#  'clay',
#  'clean',
#  'cleaning',
#  'clear',
#  'click',
#  'client',
#  'climb',
#  'clip',
#  'clock',
#  'close',
#  'closed',
#  'closer',
#  'closest',
#  'closing',
#  'clothes',
#  'clothing',
#  'cloud',
#  'club',
#  'clue',
#  'clumsy',
#  'coach',
#  'code',
#  'cold',
#  'collaboration',
#  'collapse',
#  'colleague',
#  'collect',
#  'collected',
#  'collecting',
#  'collection',
#  'college',
#  'colonized',
#  'colony',
#  'color',
#  'colored',
#  'colorful',
#  'combat',
#  'combination',
#  'combine',
#  'combined',
#  'combining',
#  'come',
#  'comedic',
#  'comedy',
#  'comet',
#  'comfort',
#  'comfortable',
#  'comic',
#  'comical',
#  'coming',
#  'command',
#  'commander',
#  'commercial',
#  'commissioned',
#  'commit',
#  'committed',
#  'common',
#  'community',
#  'companion',
#  'company',
#  'compete',
#  'competing',
#  'competition',
#  'competitive',
#  'compilation',
#  'complete',
#  'completed',
#  'completely',
#  'completing',
#  'complex',
#  'complicated',
#  'composed',
#  'comprised',
#  'computer',
#  'comrade',
#  'conan',
#  'concept',
#  'concern',
#  'concerned',
#  'concerning',
#  'concert',
#  'conclusion',
#  'condition',
#  'confess',
#  'confesses',
#  'confidence',
#  'conflict',
#  'confront',
#  'confrontation',
#  'confronted',
#  'confused',
#  'confusion',
#  'connected',
#  'connection',
#  'conquer',
#  'conquering',
#  'conquest',
#  'consciousness',
#  'consequence',
#  'consider',
#  'considered',
#  'consisting',
#  'consists',
#  'conspiracy',
#  'constant',
#  'constantly',
#  'construction',
#  'contact',
#  'contain',
#  'contained',
#  'containing',
#  'contains',
#  'content',
#  'contest',
#  'continent',
#  'continuation',
#  'continue',
#  'continued',
#  'continues',
#  'continuing',
#  'contract',
#  'control',
#  'controlled',
#  'controlling',
#  'convenience',
#  'convention',
#  'conversation',
#  'convince',
#  'convinced',
#  'cook',
#  'cooking',
#  'cool',
#  'cooperation',
#  'cop',
#  'cope',
#  'core',
#  'corner',
#  'corp',
#  'corporation',
#  'corrupt',
#  'corruption',
#  'cosmic',
#  'cost',
#  'costume',
#  'council',
#  'count',
#  'counter',
#  'countless',
#  'country',
#  'countryside',
#  'couple',
#  'courage',
#  'courageous',
#  'course',
#  'court',
#  'cousin',
#  'cover',
#  'covered',
#  'covering',
#  'craft',
#  'crash',
#  'crashed',
#  'crazy',
#  'create',
#  'created',
#  'creates',
#  'creating',
#  'creation',
#  'creator',
#  'creature',
#  'credit',
#  'crew',
#  'crime',
#  'criminal',
#  'crimson',
#  'crisis',
#  'critical',
#  'cross',
#  'crossover',
#  'crow',
#  'crowd',
#  'crown',
#  'cruel',
#  'crush',
#  'crystal',
#  'culprit',
#  'cult',
#  'cultural',
#  'culture',
#  'cup',
#  'cure',
#  'curiosity',
#  'curious',
#  'current',
#  'currently',
#  'curse',
#  'cursed',
#  'curtain',
#  'custom',
#  'customer',
#  'cut',
#  'cute',
#  'cyber',
#  'cyborg',
#  'cycle',
#  'dad',
#  'dai',
#  'daily',
#  'daisuke',
#  'damage',
#  'dan',
#  'dance',
#  'dancer',
#  'dancing',
#  'danger',
#  'dangerous',
#  'dare',
#  'dark',
#  'darker',
#  'darkness',
#  'data',
#  'date',
#  'dating',
#  'daughter',
#  'dawn',
#  'day',
#  'dead',
#  'deadly',
#  'deal',
#  'dealing',
#  'dear',
#  'death',
#  'debt',
#  'debut',
#  'decade',
#  'deceased',
#  'december',
#  'decide',
#  'decided',
#  'decides',
#  'deciding',
#  'decision',
#  'declares',
#  'dedicated',
#  'deed',
#  'deep',
#  'deeper',
#  'deeply',
#  'defeat',
#  'defeated',
#  'defeating',
#  'defend',
#  'defender',
#  'defending',
#  'defense',
#  'definitely',
#  'deformed',
#  'deity',
#  'delicious',
#  'delinquent',
#  'deliver',
#  'delivery',
#  'demand',
#  'demon',
#  'demonic',
#  'department',
#  'depict',
#  'depicted',
#  'depicting',
#  'depicts',
#  'depth',
#  'descendant',
#  'described',
#  'desert',
#  'deserted',
#  'design',
#  'designed',
#  'designer',
#  'desire',
#  'desolate',
#  'despair',
#  'desperate',
#  'desperately',
#  'desperation',
#  'despite',
#  'destination',
#  'destined',
#  'destiny',
#  'destroy',
#  'destroyed',
#  'destroying',
#  'destroys',
#  'destruction',
#  'destructive',
#  'detective',
#  'determination',
#  'determine',
#  'determined',
#  'devastated',
#  'devastating',
#  'develop',
#  'developed',
#  'developing',
#  'development',
#  'develops',
#  'device',
#  'devil',
#  'dialogue',
#  'diamond',
#  'diary',
#  'die',
#  'died',
#  'difference',
#  'different',
#  'difficult',
#  'difficulty',
#  'digimon',
#  'digital',
#  'dilemma',
#  'dimension',
#  'dimensional',
#  'dinner',
#  'dinosaur',
#  'direct',
#  'directed',
#  'direction',
#  'directly',
#  'director',
#  'dirty',
#  'disappear',
#  'disappearance',
#  'disappeared',
#  'disappearing',
#  'disappears',
#  'disaster',
#  'disc',
#  'disciple',
#  'discover',
#  'discovered',
#  'discovering',
#  'discovers',
#  'discovery',
#  'discrimination',
#  'discus',
#  'disease',
#  'disguise',
#  'disguised',
#  'dish',
#  'dislike',
#  'dispatch',
#  'display',
#  'distance',
#  'distant',
#  'distress',
#  'district',
#  'disturbing',
#  'dive',
#  'divided',
#  'divine',
#  'division',
#  'dna',
#  'doctor',
#  'documentary',
#  'dog',
#  'doll',
#  'domination',
#  'doom',
#  'door',
#  'doraemon',
#  'dorm',
#  'double',
#  'doubt',
#  'drag',
#  'dragged',
#  'dragon',
#  'drama',
#  'draw',
#  'drawing',
#  'drawn',
#  'dream',
#  'dreamed',
#  'dreaming',
#  'dress',
#  'dressed',
#  'dressing',
#  'drift',
#  'drink',
#  'drinking',
#  'drive',
#  'driven',
#  'driver',
#  'driving',
#  'drop',
#  'dropped',
#  'drowning',
#  'drug',
#  'dry',
#  'dubbed',
#  'duel',
#  'duelist',
#  'duke',
#  'dull',
#  ...]

# %%
#skip characters_sim to save RAM

#use euclidean distance because feature has a lot of zero-vectors
similarity = np.multiply(similarity,similarity_matrix(animes['Staffs'].str.get_dummies(",")))
#characters_sim = similarity_matrix(animes['Characters'].str.get_dummies(","))

# %%
#get years from aired dates
animes['aired_from'] = animes['aired_from'].apply(lambda x: int(x[0:4]))

# %%
#use eucliean since all three features are numeric values with magnitude
similarity = np.multiply(similarity,similarity_matrix(animes['rank'].values.reshape(-1,1)))
similarity = np.multiply(similarity,similarity_matrix(animes['popularity'].values.reshape(-1,1)))
similarity = np.multiply(similarity,similarity_matrix(animes['aired_from'].values.reshape(-1,1)))

# %%
#use similarity matrix to get top 7 recommendations for chosen show. 
#Top entry is item itself since identical items have perfect similarity with itself
def recommend_by_id(id):
    #sort by similarity for item
    similar_animes = sorted(list(enumerate(similarity[id])),key=lambda x:x[1],reverse=True)
    #print top 7 recommendation
    for anime in similar_animes[0:7]:
        print(animes["title"][anime[0]])
recommend_by_id(16)
# Out:
# Kimi ni Todoke
# Kimi ni Todoke 2nd Season
# Gekkan Shoujo Nozaki-kun
# ReLIFE
# K-On!!
# Toki wo Kakeru Shoujo
# Hyouka

# %% [markdown]
# ##Evaludation of recommendation model
#
# From the result above, the content recommendation seems to be working quite well! Kimi ni Todoke is a school-themed highschool romance series and so are the other animes that are being recommended. All of them have school/romance elements and the top recommendation is its sequel which should be a very natural recommendation. However, generalizing on just few results doesn't do justice.
#
# ### Ideas for improvments
# 1. **Use a hit rate metrics to measure performance of the model:**
#     Using a hit rate is better than taking the average rating of the items and calculating the error against real rating
#     because accurate rating does not imply that the user will like that item. Hit rate is better because recommendation is
#     already in a top-N list format. Or ranking-loss might even work better as a matrix
# 2. **Using other features**: For this model, we only used a few features which we think is important with characteristics of the show. But, perhaps trying out other features may increase its performance as well.
# 3. **Different method for similarity score**: For now, we were just multiplying each similarity matrix to obtain overall similarity
# Obviously similarity in one feature may be more important than other feature so using each similarity measure as a feature to regression model may help in assigning approperiate weightings to each feature.
# 4. **Better NLP techniques**: As seen in the list of feature names, some of the words still contained character's names which are irrelevant to the plot. Removing these names manually may also help extract better features. Also a lot of them contain numbers which are also irrelevant to the plot.
